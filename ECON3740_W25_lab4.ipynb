# %% [markdown]
# <a href="https://colab.research.google.com/github/havaledar/ECON3740_W25/blob/main/ECON3740_W25_lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Computer Assignment 4
#
# The first exercise C2 uses a variation of HPRICE1, which is cross-sectional individual data containing information on Boston, Massachusetts area gathered from the real estate pages of the Boston Globe during 1990.
#
# NOTE: When computing the residual in (vi), the answer is in dollars, not thousands. For instance, if the residual were say "5" you need to enter it as $5000.
#
# For the second exercise C4, you will be using a variation of ATTEND, which is cross-sectional individual data containing information on students' class attendance, cumulative GPA, ACT scores, and other variables gathered from Principles of Microeconomics students at Michigan State University.
#
# NOTE: At the end of (iv), the TRUE/FALSE where the predicted attendance rate is more than 100%, an attendance rate above 100% is considered wrong and it needs to be truncated to 100%. I disagree, as I think that how to report predictions outside a feasible interval is a matter of opinion (but the correct answer is FALSE).
# Also, in (v), the answer should have said "percentage points" not "%" (but it is otherwise correct).

# %% [markdown]
# # Libraries

# %%
import pandas as pd

# %% [markdown]
# # Reading Stata Files

# %% [markdown]
# ## Download LFS data

# %% [markdown]
# Download LFS from Odesi Nesstar first from https://odesi.ca/en

# %% [markdown]
# ## read_stata

# %% [markdown]
# Once the file is uploaded and the libraries you are going to use imported, you can read it into a DataFrame.
#
# ```python
# data = pd.read_stata('file.dta')
# ```
#
# Make sure the filename matches the uploaded file.
#
# You can also reference the full Google Colab filesystem path if needed:
#
# ```
# data = pd.read_stata('/content/file.dta')
# ```
#
# For example, we can import a dta file of survey data downloaded from a website:
#
# To read a dta file into a DataFrame:
#
# ```python
# data = pd.read_stata('LFS-71M0001-E-2023-August_F1.dta')
# ```
#
# Pandas will automatically convert the data into a DataFrame.
#
# Here is the documentation for read_stata.
# https://colab.research.google.com/corgiredirector?site=https%3A%2F%2Fpandas.pydata.org%2Fdocs%2Freference%2Fapi%2Fpandas.read_stata.html

# %% [markdown]
# ## Labels or Values
#
# When you are reading the dta files, you can indicate if you need the values(convert_categoricals = False) or the lables(convert_categoricals = True) for the categorical variables as below. The read_stata by default read the lables not the values.
#
# ```python
# data = pd.read_stata('LFS-71M0001-E-2023-August_F1.dta', convert_categoricals=False)
# ```

# %%
data_stata_labels = pd.read_stata("/content/LFS-71M0001-E-2022-February_F1.dta")
data_stata_labels
# Out:
#         REC_NUM  SURVYEAR  SURVMNTH              LFSSTAT  \
# 0             1      2022  February  Not in labour force
# 1             2      2022  February  Not in labour force
# 2             3      2022  February  Not in labour force
# 3             4      2022  February  Not in labour force
# 4             5      2022  February  Not in labour force
# ...         ...       ...       ...                  ...
# 103653   103654      2022  February    Employed, at work
# 103654   103655      2022  February    Employed, at work
# 103655   103656      2022  February    Employed, at work
# 103656   103657      2022  February    Employed, at work
# 103657   103658      2022  February    Employed, at work
#
#                              PROV                   CMA          AGE_12  \
# 0                         Ontario               Toronto  15 to 19 years
# 1       Newfoundland and Labrador  Other CMA or non-CMA  20 to 24 years
# ...

# %%
data_stata_values = pd.read_stata('/content/LFS-71M0001-E-2022-February_F1.dta', convert_categoricals=True)
data_stata_values
# Out:
#         REC_NUM  SURVYEAR  SURVMNTH              LFSSTAT  \
# 0             1      2022  February  Not in labour force
# 1             2      2022  February  Not in labour force
# 2             3      2022  February  Not in labour force
# 3             4      2022  February  Not in labour force
# 4             5      2022  February  Not in labour force
# ...         ...       ...       ...                  ...
# 103653   103654      2022  February    Employed, at work
# 103654   103655      2022  February    Employed, at work
# 103655   103656      2022  February    Employed, at work
# 103656   103657      2022  February    Employed, at work
# 103657   103658      2022  February    Employed, at work
#
#                              PROV                   CMA          AGE_12  \
# 0                         Ontario               Toronto  15 to 19 years
# 1       Newfoundland and Labrador  Other CMA or non-CMA  20 to 24 years
# ...

# %% [markdown]
# ## Description

# %%
data_stata = pd.read_stata('/content/LFS-71M0001-E-2022-February_F1.dta', iterator=True)
data_stata.variable_labels()
# Out:
# {'REC_NUM': 'Order of record in file',
#  'SURVYEAR': 'Survey year',
#  'SURVMNTH': 'Survey month',
#  'LFSSTAT': 'Labour force status',
#  'PROV': 'Province',
#  'CMA': 'Nine largest CMAs',
#  'AGE_12': 'Five-year age group of respondent',
#  'AGE_6': 'Age in 2 and 3 year groups, 15 to 29',
#  'SEX': 'Sex of respondent',
#  'MARSTAT': 'Marital status of respondent',
#  'EDUC': 'Highest educational attainment',
#  'MJH': 'Single or multiple jobholder',
#  'EVERWORK': 'Not currently employed, worked in the past',
#  'FTPTLAST': 'Full- or part-time status of last job',
#  'COWMAIN': 'Class of worker, main job',
#  'IMMIG': 'Immigration status',
#  'NAICS_21': 'Industry of main job',
#  'NOC_10': 'Occupation at main job',
#  'NOC_40': 'Occupation at main job',
#  'YABSENT': 'Reason of absence, full week',
#  'WKSAWAY': 'Number of weeks absent from work',
#  'PAYAWAY': 'Paid for time off, full-week absence only',
#  'UHRSMAIN': 'Usual hours worked per week at main job',
# ...

# %% [markdown]
# ## Type

# %%
data_stata_type = pd.read_stata('/content/LFS-71M0001-E-2022-February_F1.dta', preserve_dtypes=False)
data_stata_type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103658 entries, 0 to 103657
# Data columns (total 60 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   REC_NUM   103658 non-null  int64
#  1   SURVYEAR  103658 non-null  int64
#  2   SURVMNTH  103658 non-null  category
#  3   LFSSTAT   103658 non-null  category
#  4   PROV      103658 non-null  category
#  5   CMA       103658 non-null  category
#  6   AGE_12    103658 non-null  category
#  7   AGE_6     19184 non-null   category
#  8   SEX       103658 non-null  category
#  9   MARSTAT   103658 non-null  category
#  10  EDUC      103658 non-null  category
#  11  MJH       59943 non-null   category
#  12  EVERWORK  43715 non-null   category
#  13  FTPTLAST  7119 non-null    category
#  14  COWMAIN   67062 non-null   category
#  15  IMMIG     103658 non-null  category
#  16  NAICS_21  67062 non-null   category
#  17  NOC_10    67062 non-null   category
# ...

# %% [markdown]
# You can check the not null values with both info and describe.

# %% [markdown]
# ## pyreadstat

# %%
# !pip install pyreadstat
import pyreadstat
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 26.7 MB/s eta 0:00:00
# ...

# %%
d, meta = pyreadstat.read_dta('/content/LFS-71M0001-E-2022-February_F1.dta')

# %%
d
# Out:
#         REC_NUM  SURVYEAR  SURVMNTH  LFSSTAT  PROV  CMA  AGE_12 AGE_6  SEX  \
# 0             1      2022         2        4    35    4       1     1    2
# 1             2      2022         2        4    10    0       2     4    2
# 2             3      2022         2        4    35    0       7   NaN    2
# 3             4      2022         2        4    24    2      12   NaN    1
# 4             5      2022         2        4    47    0      10   NaN    1
# ...         ...       ...       ...      ...   ...  ...     ...   ...  ...
# 103653   103654      2022         2        1    48    0       9   NaN    1
# 103654   103655      2022         2        1    35    5       5   NaN    1
# 103655   103656      2022         2        1    24    0      10   NaN    2
# 103656   103657      2022         2        1    59    9       6   NaN    2
# 103657   103658      2022         2        1    13    0       6   NaN    1
#
# ...

# %%
print(meta.column_labels)
# Out:
# ['Order of record in file', 'Survey year', 'Survey month', 'Labour force status', 'Province', 'Nine largest CMAs', 'Five-year age group of respondent', 'Age in 2 and 3 year groups, 15 to 29', 'Sex of respondent', 'Marital status of respondent', 'Highest educational attainment', 'Single or multiple jobholder', 'Not currently employed, worked in the past', 'Full- or part-time status of last job', 'Class of worker, main job', 'Immigration status', 'Industry of main job', 'Occupation at main job', 'Occupation at main job', 'Reason of absence, full week', 'Number of weeks absent from work', 'Paid for time off, full-week absence only', 'Usual hours worked per week at main job', 'Actual hours worked per week at main job', 'Full- or part-time status at main or only job', 'Usual hours worked per week at all jobs', 'Actual hours worked per week at all jobs', 'Hours away from work, part-week absence only', 'Reason for part-week absence', 'Paid overtime hours in reference week', 'Unpaid overtime
# ...

# %%
meta.variable_value_labels['SURVMNTH']
# Out:
# {1: 'January',
#  2: 'February',
#  3: 'March',
#  4: 'April',
#  5: 'May',
#  6: 'June',
#  7: 'July',
#  8: 'August',
#  9: 'September',
#  10: 'October',
#  11: 'November',
#  12: 'December'}

# %% [markdown]
# # Recent datasets

# %%
pd.read_spss('/content/LFS_June_2024 (1).sav', convert_categoricals=False)
# Out:
#          REC_NUM  SURVYEAR  SURVMNTH  LFSSTAT  PROV  CMA  AGE_12  AGE_6  SEX  \
# 0            1.0    2024.0       6.0      1.0  48.0  0.0     4.0    NaN  2.0
# 1            2.0    2024.0       6.0      2.0  24.0  2.0     5.0    NaN  2.0
# 2            3.0    2024.0       6.0      1.0  13.0  0.0     4.0    NaN  1.0
# 3            4.0    2024.0       6.0      4.0  11.0  0.0     8.0    NaN  2.0
# 4            5.0    2024.0       6.0      1.0  59.0  9.0     4.0    NaN  2.0
# ...          ...       ...       ...      ...   ...  ...     ...    ...  ...
# 113103  113104.0    2024.0       6.0      4.0  11.0  0.0    12.0    NaN  2.0
# 113104  113105.0    2024.0       6.0      1.0  35.0  0.0    10.0    NaN  2.0
# 113105  113106.0    2024.0       6.0      4.0  35.0  0.0    10.0    NaN  1.0
# 113106  113107.0    2024.0       6.0      1.0  24.0  1.0     8.0    NaN  2.0
# 113107  113108.0    2024.0       6.0      4.0  47.0  0.0    11.0    NaN  2.0
#
# ...

# %%
d1, m1 = pyreadstat.read_dta('/content/LFS-71M0001-E-2022-February_F1.dta')

# %%
d1
# Out:
#         REC_NUM  SURVYEAR  SURVMNTH  LFSSTAT  PROV  CMA  AGE_12 AGE_6  SEX  \
# 0             1      2022         2        4    35    4       1     1    2
# 1             2      2022         2        4    10    0       2     4    2
# 2             3      2022         2        4    35    0       7   NaN    2
# 3             4      2022         2        4    24    2      12   NaN    1
# 4             5      2022         2        4    47    0      10   NaN    1
# ...         ...       ...       ...      ...   ...  ...     ...   ...  ...
# 103653   103654      2022         2        1    48    0       9   NaN    1
# 103654   103655      2022         2        1    35    5       5   NaN    1
# 103655   103656      2022         2        1    24    0      10   NaN    2
# 103656   103657      2022         2        1    59    9       6   NaN    2
# 103657   103658      2022         2        1    13    0       6   NaN    1
#
# ...
